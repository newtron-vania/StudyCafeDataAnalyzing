# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import re

# 크롬 브라우저 열기
driver = webdriver.Chrome('chromedriver.exe') 

driver.get('https://www.instargram.com')
time.sleep(2)

# %%
def insta_searching(word):
    url = "https://www.instagram.com/explore/tags/" + word
    return url
import time

# %%
email = '01082810136' 
input_id = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[0]
input_id.clear()
input_id.send_keys(email)

password = '3977871' 
input_pw = driver.find_elements_by_css_selector('input._2hvTZ.pexuQ.zyHYP')[1]
input_pw.clear()
input_pw.send_keys(password)
input_pw.submit()

# %%
def select_first(driver):
    first = driver.find_element_by_css_selector("div._9AhH0")
    first.click()
    time.sleep(3)

# %%
import re
from bs4 import BeautifulSoup

def get_content(driver):
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'lxml')
    # 본문 내용 
    try:
        content = soup.select('div.C4VMK > span')[0].text
    except:
        content = ' '
    # 해시태그 
    tags = re.findall(r'#[^\s#,\\]+', content)  
   
    data = [content, tags]
    return data

# %%
def move_next(driver):

    right = driver.find_element_by_css_selector ('a.coreSpriteRightPaginationArrow')
    right.click()
    time.sleep(1)

# %%
word = "스터디카페창업"
url = insta_searching(word)
driver.get(url)

time.sleep(3)

select_first(driver)

results = [ ]

target = 100
for i in range(target):
    
    try:
        data = get_content(driver)  
        results.append(data)
        move_next(driver)
    except:
        time.sleep(1)
        move_next(driver)
    

print(results[:2])
# Out:
# [['챌린지스터다카페는 혁신적인 시스템으로 남다른 스터디카페 문화를 선도합니다.☆공간에 대한 고민☆우리는 더 완벽한 공간을 만들고 싶습니다.더 오래 더 많은 사랑을 받는 공간으로 만들기위해우리만의 경쟁력을 키웠습니다.☆상생에 대한 고민☆챌린지스터디카페는 점주님과 결합하여 상생하는 시스템을만들어 나가겠습니다. 학습자들에게는 다양한 꿈을 이루는 공간을창업자에게는 완벽한 성공을 안겨 드리겠습니다.챌린지스터디카페 창업이 궁금하시다면창업문의 1577-9351로 연락주시기 바랍니다^^..#스터디카페창업 #창업 #카페창업 #스터디카페 #창업문의 #스터디카페 #챌린지스터디카페 #여성창업 #남성창업 #퇴직후창업 #카공족 #스터디카페추천', ['#스터디카페창업', '#창업', '#카페창업', '#스터디카페', '#창업문의', '#스터디카페', '#챌린지스터디카페', '#여성창업', '#남성창업', '#퇴직후창업', '#카공족', '#스터디카페추천']], ['예비점주님들을 위한 이병훈 소장 특별 강연 이벤트를진행합니다^^챌린지스터디카페 오픈1~3개월 후스타강사 이병훈 소장이 직접 매장을 방문하여강연을 합니다^^학습자들에게는 공부의 기회를 점주님들께는홍보의 기회를 드릴 수 있는 절호의 찬스!!창업문의 1577-9351..#이병훈 #이병훈소장 #이병훈강연 #이병훈소장강연 #스터디카페창업 #스터디카페 #창업반클래스#창업준비 #창업문의 #사업아이템 #스터디카페창업 #스터디카페추천 #창업추천 #초보창업 #창업초보 #창업상담 #창업스타그램 #창업설명회 #창업준비중 #소자본창업추천 #소자본창업', ['#이병훈', '#이병훈소장', '#이병훈강연', '#이병훈소장강연', '#스터디카페창업', '#스터디카페', '#창업반클래스', '#창업준비', '#창업문의', '#사업아이템', '#스터디카페창업', '#스터디카페추천', '#창업추천', '#초보창업', '#창업초보', '#창업상담', '#창업스타그램', '#창업설명회', '#창업준비중', '#소자본창업추천', '#소자본창업']]]

# %%
word = "스터디카페"
url = insta_searching(word)
driver.get(url)

time.sleep(3)

select_first(driver)

results2 = [ ]

target = 100  
for i in range(target):
    
    try:
        data = get_content(driver)  
        results2.append(data)
        move_next(driver)
    except:
        time.sleep(2)
        move_next(driver)
    

print(results[:2])
# Out:
# [['챌린지스터다카페는 혁신적인 시스템으로 남다른 스터디카페 문화를 선도합니다.☆공간에 대한 고민☆우리는 더 완벽한 공간을 만들고 싶습니다.더 오래 더 많은 사랑을 받는 공간으로 만들기위해우리만의 경쟁력을 키웠습니다.☆상생에 대한 고민☆챌린지스터디카페는 점주님과 결합하여 상생하는 시스템을만들어 나가겠습니다. 학습자들에게는 다양한 꿈을 이루는 공간을창업자에게는 완벽한 성공을 안겨 드리겠습니다.챌린지스터디카페 창업이 궁금하시다면창업문의 1577-9351로 연락주시기 바랍니다^^..#스터디카페창업 #창업 #카페창업 #스터디카페 #창업문의 #스터디카페 #챌린지스터디카페 #여성창업 #남성창업 #퇴직후창업 #카공족 #스터디카페추천', ['#스터디카페창업', '#창업', '#카페창업', '#스터디카페', '#창업문의', '#스터디카페', '#챌린지스터디카페', '#여성창업', '#남성창업', '#퇴직후창업', '#카공족', '#스터디카페추천']], ['예비점주님들을 위한 이병훈 소장 특별 강연 이벤트를진행합니다^^챌린지스터디카페 오픈1~3개월 후스타강사 이병훈 소장이 직접 매장을 방문하여강연을 합니다^^학습자들에게는 공부의 기회를 점주님들께는홍보의 기회를 드릴 수 있는 절호의 찬스!!창업문의 1577-9351..#이병훈 #이병훈소장 #이병훈강연 #이병훈소장강연 #스터디카페창업 #스터디카페 #창업반클래스#창업준비 #창업문의 #사업아이템 #스터디카페창업 #스터디카페추천 #창업추천 #초보창업 #창업초보 #창업상담 #창업스타그램 #창업설명회 #창업준비중 #소자본창업추천 #소자본창업', ['#이병훈', '#이병훈소장', '#이병훈강연', '#이병훈소장강연', '#스터디카페창업', '#스터디카페', '#창업반클래스', '#창업준비', '#창업문의', '#사업아이템', '#스터디카페창업', '#스터디카페추천', '#창업추천', '#초보창업', '#창업초보', '#창업상담', '#창업스타그램', '#창업설명회', '#창업준비중', '#소자본창업추천', '#소자본창업']]]

# %%
import pandas as pd

f = open('인스타그램 스터디카페.txt', 'w', encoding='UTF-8')
for content, tag in results:
    f.write(content)
    f.wirte('\n')
    f.write(str(tag))
    f.wirte(\n)
f.close()

# %%
results_new = []
for content, tag in results:
    tag = re.sub(r"\W"," ",str(tag))
    tag = re.sub(r"\d"," ",str(tag))
    tag = re.sub(r"\s+[a-z]\s+"," ",str(tag))
    tag = re.sub(r"\s+[a-z]$"," ",str(tag))
    tag = re.sub(r"^[a-z]\s+"," ",str(tag))
    tag = re.sub(r"\s+"," ",str(tag))
    
    tag = ''.join(str(tag)).replace("#"," ")
    results_new.append(tag)
results_new
# Out:
# [' 스터디카페창업 창업 카페창업 스터디카페 창업문의 스터디카페 챌린지스터디카페 여성창업 남성창업 퇴직후창업 카공족 스터디카페추천 ',
#  ' 이병훈 이병훈소장 이병훈강연 이병훈소장강연 스터디카페창업 스터디카페 창업반클래스 창업준비 창업문의 사업아이템 스터디카페창업 스터디카페추천 창업추천 초보창업 창업초보 창업상담 창업스타그램 창업설명회 창업준비중 소자본창업추천 소자본창업 ',
#  ' 스터디카페 챌린지스터디카페 스터디카페이벤트 창업이벤트 스터디카페창업 창업 독서실창업 초 초특가이벤트 ',
#  ' 창업이벤트 창업 스터디카페창업 소자본창업 스터디카페창업이벤트 이벤트 소자본창업 창업방법 대창업 대창업 대창업 퇴직후창업 이벤트그램 이벤트참여 ',
#  ' 스터디카페인테리어 독서실인테리어 스터디카페전문 인베이 무인스터디카페인테리어 무인스터디카페 무인스터디카페창업 무인스터디카페창업비용 스터디카페창업비용 스터디카페견적 스터디카페견적비용 스터디카페키오스크 키오스크 무인독서실 스터디카페견적문의 독서실창업상담 독서실창업비용 독서실창업전문 스터디카페창업전문 무인카페창업비용 시스터디카페 인베이프랜차이즈 독서실인테리어견적 무인키오스크렌탈 무인키오스크 인베이스터디카페 인테리어 스터디카페창업 ',
#  ' 상업인테리어 스터디카페인테리어 인베이스터디카페 인베이프랜차이즈 독서실인테리어 스터디카페전문 인베이 무인스터디카페인테리어 무인스터디카페 무인스터디카페창업 무인스터디카페창업비용 스터디카페창업비용 스터디카페견적 스터디카페견적비용 스터디카페키오스크 키오스크 스터디카페견적문의 독서실창업상담 독서실창업비용 독서실창업전문 스터디카페창업전문 무인카페창업비용 시스터디카페 독서실인테리어견적 무인키오스크렌탈 무인키오스크 인테리어 스터디카페창업 ',
# ...

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')
# 본문 내용 
try:
    content = soup.select('div.C4VMK > span')[0].text
except:
    content = ' '
# 해시태그 
tags = re.findall(r'#[^\s#,\\]+', content)  
   
data = [content, tags]
print(data)
# Out:
# ['-생각에서 실천하기까지 조금 오래걸린 것 같습니다 아직은 살만한 세상을 위해 이제부터 함께 동참합니다☀️#커피랑도서관강북본점 은 #선한영향력가게 동행점포입니다 #아동급식카드 #지드림카드 (G-dream)와함께 방문해주세요 :) 궁금하신 사항은 문의주세요~! 우리 마음껏 공부하자요~!!😊', ['#커피랑도서관강북본점', '#선한영향력가게', '#아동급식카드', '#지드림카드']]

# %%
results2
# Out:
# []
